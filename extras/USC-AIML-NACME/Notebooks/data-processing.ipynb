# %%
# Licensed under the Apache License, Version 2.0 (the "License");
# you may not use this file except in compliance with the License.
# You may obtain a copy of the License at
#
# https://www.apache.org/licenses/LICENSE-2.0
#
# Unless required by applicable law or agreed to in writing, software
# distributed under the License is distributed on an "AS IS" BASIS,
# WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# See the License for the specific language governing permissions and
# limitations under the License.

# %% [markdown]
# # Dataset Exploration

# %% [markdown]
# For this project you will be given a dataset and an associated problem. Over the course of the day, you will explore the dataset and train the best model you can in order to solve the problem. At the end of the day, you will give a short presentation about your model and solution.

# %% [markdown]
# ### Deliverables
#
# 1. An **up to this Notebook** containing your code and responses to the ethical considerations below.
# 1. At the end of the day, we will ask you and your group to stand in front of the class and give a brief **presentation about what you have done**.

# %% [markdown]
# ## Team
#
# Please enter your team members' names in the placeholders in this text area:
#
# *   Darryn Dunn
# *   Samuel Ovalle
# *   Camile Reese

# %% [markdown]
# # Exercises

# %% [markdown]
# ## Exercise 1: Coding

# %% [markdown]
# [Kaggle](http://www.kaggle.com) hosts a [dataset containing US airline on-time statistics and delay data](https://www.kaggle.com/giovamata/airlinedelaycauses) from the [US Department of Transportation's Bureau of Transportation Statistics (BTS)](https://www.bts.gov/). In this project, we will **use flight statistics data to gain insights into US airports' and airlines' flights in 2008.**
#
# You are free to use any toolkit we've covered in class to solve the problem (e.g. Pandas, Matplotlib, Seaborn).
#
# Demonstrations of competency:
# 1. Get the data into a Python object.
# 1. Inspect the data for each column's data type and summary statistics.
# 1. Explore the data programmatically and visually.
# 1. Produce an answer and visualization, where applicable, for at least three questions from the list below, and discuss any relevant insights. Feel free to generate and answer some of your own questions.
#
#   * Which U.S. airport is the busiest airport? You can decide how you'd like to measure "business" (e.g., annually, monthly, daily).
#   * Of the 2008 flights that are *actually delayed*, think about:
#     * Which 10 U.S. airlines have the most delays?
#     * Which 10 U.S. airlines have the longest average delay time?
#     * Which 10 U.S. airports have the most delays?
#     * Which 10 U.S. airports have the longest average delay time?
#   * More analysis:
#     * Are there patterns on how flight delays are distributed across different hours of the day?
#     * How about across months or seasons? Can you think of any reasons for these seasonal delays?
#     * If you look at average delay time or number of delays by airport, does the data show linearity? Does any subset of the data show linearity?
#     * Add reason for delay to your delay analysis above.
#     * Examine flight frequencies, delays, time of day or year, etc. for a specific airport, airline or origin-arrival airport pair.

# %% [markdown]
# ### Student Group Solution
# Feel free to add as many code cells as needed to complete the project.

# %%
import pandas as pd

# Demonstrating Compentency
################################################################

# Getting data into python object: Pandas DataFrame
df = pd.read_csv("DelayedFlights.csv")
df

################################################################
# Out:
#          Unnamed: 0  Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 0                 0  2008      1           3          4   2003.0        1955
# 1                 1  2008      1           3          4    754.0         735
# 2                 2  2008      1           3          4    628.0         620
# 3                 4  2008      1           3          4   1829.0        1755
# 4                 5  2008      1           3          4   1940.0        1915
# ...             ...   ...    ...         ...        ...      ...         ...
# 1936753     7009710  2008     12          13          6   1250.0        1220
# 1936754     7009717  2008     12          13          6    657.0         600
# 1936755     7009718  2008     12          13          6   1007.0         847
# 1936756     7009726  2008     12          13          6   1251.0        1240
# 1936757     7009727  2008     12          13          6   1110.0        1103
#
# ...

# %%
# Demonstrating Compentency
################################################################

# Inspect each column's data type
df.dtypes

################################################################
# Out:
# Unnamed: 0             int64
# Year                   int64
# Month                  int64
# DayofMonth             int64
# DayOfWeek              int64
# DepTime              float64
# CRSDepTime             int64
# ArrTime              float64
# CRSArrTime             int64
# UniqueCarrier         object
# FlightNum              int64
# TailNum               object
# ActualElapsedTime    float64
# CRSElapsedTime       float64
# AirTime              float64
# ArrDelay             float64
# DepDelay             float64
# Origin                object
# Dest                  object
# Distance               int64
# TaxiIn               float64
# TaxiOut              float64
# Cancelled              int64
# CancellationCode      object
# Diverted               int64
# CarrierDelay         float64
# WeatherDelay         float64
# NASDelay             float64
# SecurityDelay        float64
# LateAircraftDelay    float64
# dtype: object

# %%
# Demonstrating Compentency
################################################################

# Display the summary statistics for numeric data
df.describe()

################################################################
# Out:
#          Unnamed: 0       Year         Month    DayofMonth     DayOfWeek  \
# count  1.936758e+06  1936758.0  1.936758e+06  1.936758e+06  1.936758e+06
# mean   3.341651e+06     2008.0  6.111106e+00  1.575347e+01  3.984827e+00
# std    2.066065e+06        0.0  3.482546e+00  8.776272e+00  1.995966e+00
# min    0.000000e+00     2008.0  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    1.517452e+06     2008.0  3.000000e+00  8.000000e+00  2.000000e+00
# 50%    3.242558e+06     2008.0  6.000000e+00  1.600000e+01  4.000000e+00
# 75%    4.972467e+06     2008.0  9.000000e+00  2.300000e+01  6.000000e+00
# max    7.009727e+06     2008.0  1.200000e+01  3.100000e+01  7.000000e+00
#
#             DepTime    CRSDepTime       ArrTime    CRSArrTime     FlightNum  \
# count  1.936758e+06  1.936758e+06  1.929648e+06  1.936758e+06  1.936758e+06
# mean   1.518534e+03  1.467473e+03  1.610141e+03  1.634225e+03  2.184263e+03
# std    4.504853e+02  4.247668e+02  5.481781e+02  4.646347e+02  1.944702e+03
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# Which airport is the busiest
# (Explore the data programmatically/visually)
################################################################

# We decided to determine which airport had the most flights annually
# This can be done by using the destination column 'Dest' and departure column 'Origin'
# This is because all of the data is from a single year (2008)
# This will allow us to create counts for each airport and compare them in one chart
# We will also need to remove cancelled flights as they may skew data incorrectly

# Checking for rows we may need to eliminate due to null values:
print(f"Is there null values in the destination column: {df['Dest'].isnull().any()}")
print(f"Is there null values in the departure column: {df['Origin'].isnull().any()}")

# Discovering there are 304 unique destination airports (too many for a single bar chart)
# We will just display the top 10 values in our chart for visual simplicity
print(f"How many unique values are there in the destinations: {df['Dest'].unique().size}")
print(f"What is shown when flights are cancelled: {df['CancellationCode'].unique()}")

# removing the cancelled flights
df = df[df['CancellationCode'] == 'N']
print(f"This is the only code left after data processing: {df['CancellationCode'].unique()}")

# creating a series that contains the amount of flights to each destination in ascending order
departures_per_airport = df['Year'].groupby(df['Origin']).count()
arrivals_per_airport = df['Year'].groupby(df['Dest']).count()
#flights_per_airport = departures_per_airport + arrivals_per_airport
flights_per_airport = departures_per_airport
flights_per_airport = flights_per_airport.sort_values()

#removing null values
flights_per_airport = flights_per_airport[~flights_per_airport.isnull()]

# pulling out the top 10 destinations with the most flights to prep for plot
top_10_airports = tuple(flights_per_airport.tail(10).index)
top_10_airport_flights = tuple(flights_per_airport.tail(10).values)

#Creating the plot and highlighting the busiest airport
question1_df = pd.DataFrame({
    'Top 10 Airports': top_10_airports,
    'Flight Counts': top_10_airport_flights,
})
x_coords = np.arange(len(question1_df))

colors = ['#0000FF' for _ in range(len(question1_df))]
colors[-1] = '#FF0000'

plt.bar(x_coords, question1_df['Flight Counts'], tick_label=question1_df['Top 10 Airports'], color=colors)
plt.xticks(rotation=90)
plt.ylabel('Flights Leaving Airport')
plt.title('2008 Top 10 Busiest Airports')
plt.show()

################################################################
# Out:
# Is there null values in the destination column: False
# Is there null values in the departure column: False
# How many unique values are there in the destinations: 304
# What is shown when flights are cancelled: ['N']
# This is the only code left after data processing: ['N']

# %%
df = df[df['CancellationCode'] == 'N']

departures_per_airport = df['Year'].groupby(df['Origin']).count()
arrivals_per_airport = df['Year'].groupby(df['Dest']).count()
flights_per_airport = departures_per_airport
flights_per_airport = flights_per_airport.sort_values()

flights_per_airport = flights_per_airport[~flights_per_airport.isnull()]

top_10_airports = tuple(flights_per_airport.tail(10).index)
top_10_airport_flights = tuple(flights_per_airport.tail(10).values)

question1_df = pd.DataFrame({
    'Top 10 Airports': top_10_airports,
    'Flight Counts': top_10_airport_flights,
})
x_coords = np.arange(len(question1_df))

colors = ['#0000FF' for _ in range(len(question1_df))]
colors[-1] = '#FF0000'

plt.bar(x_coords, question1_df['Flight Counts'], 
        tick_label=question1_df['Top 10 Airports'], 
        color=colors)
plt.xticks(rotation=90)
plt.ylabel('Flights Leaving Airport')
plt.title('2008 Top 10 Busiest Airports')
plt.show()

# %%
import matplotlib.pyplot as plt

# Which month has the most delays
# (Explore the data programmatically/visually)
################################################################
#df = df[df['CancellationCode'] == 'N']

arrival_delays_monthly = df['ArrDelay'].groupby(df['Month']).count()
departure_delays_monthly = df['DepDelay'].groupby(df['Month']).count()
carrier_delays_monthly = df['CarrierDelay'].groupby(df['Month']).count()
weather_delays_monthly = df['WeatherDelay'].groupby(df['Month']).count()
NAS_delays_monthly = df['NASDelay'].groupby(df['Month']).count()
Security_delays_monthly = df['SecurityDelay'].groupby(df['Month']).count()
LateAircraft_delays_monthly = df['LateAircraftDelay'].groupby(df['Month']).count()

delays_monthly = arrival_delays_monthly + departure_delays_monthly \
  + carrier_delays_monthly + weather_delays_monthly + NAS_delays_monthly \
  + Security_delays_monthly + LateAircraft_delays_monthly

months = ("January", "February", "March", "April", "May", "June", 
          "July", "August", "September", "October", "November", "December")
delays = tuple(delays_monthly.values)

plt.plot(
  months,
  delays,
)
plt.title('2008 Delays per Month')
plt.xticks(rotation=90)
plt.ylabel('Number of Delays (millions)')
plt.xlabel('Month')
plt.show()

##These are all equivalent in count (probably directly proportional)


################################################################
# Out:
# Month
# 1     [-14.0, 2.0, 14.0, 34.0, 11.0, 57.0, 1.0, 80.0...
# 2     [12.0, 9.0, 10.0, 16.0, 57.0, 15.0, -4.0, -3.0...
# 3     [-1.0, 6.0, 10.0, 19.0, 1.0, 13.0, 16.0, 44.0,...
# 4     [47.0, 43.0, 16.0, 95.0, 12.0, 51.0, 27.0, 63....
# 5     [9.0, 18.0, -1.0, 11.0, 16.0, 81.0, 140.0, 0.0...
# 6     [1.0, 5.0, 22.0, 10.0, 4.0, 21.0, 24.0, 3.0, 1...
# 7     [13.0, 11.0, 21.0, 9.0, 10.0, -3.0, 27.0, 1.0,...
# 8     [20.0, 12.0, -1.0, -13.0, 13.0, 16.0, -4.0, 39...
# 9     [4.0, 21.0, 3.0, 36.0, -10.0, 16.0, 12.0, 17.0...
# 10    [-4.0, -9.0, 5.0, 25.0, 17.0, 2.0, -6.0, 4.0, ...
# 11    [-7.0, 15.0, -11.0, 12.0, 10.0, 6.0, 29.0, 1.0...
# 12    [41.0, 13.0, 25.0, 23.0, 20.0, 19.0, 64.0, 26....
# Name: ArrDelay, dtype: object

# %%
import seaborn as sns

arrival_delays_monthly = df['ArrDelay'].groupby(df['Month']).count()
departure_delays_monthly = df['DepDelay'].groupby(df['Month']).count()
carrier_delays_monthly = df['CarrierDelay'].groupby(df['Month']).count()
NAS_delays_monthly = df['NASDelay'].groupby(df['Month']).count()
weather_delays_monthly = df['WeatherDelay'].groupby(df['Month']).count()
security_delays_monthly = df['SecurityDelay'].groupby(df['Month']).count()
lateAircraft_delays_monthly = df['LateAircraftDelay'].groupby(df['Month']).count()


corr_df = arrival_delays_monthly.to_frame()
corr_df['DepDelay'] = departure_delays_monthly
corr_df['CarrierDelay'] = carrier_delays_monthly
corr_df['NASDelay'] = NAS_delays_monthly
corr_df['WeatherDelay'] = weather_delays_monthly
corr_df['SecurityDelay'] = security_delays_monthly
corr_df['lateAircraftDelay'] = lateAircraft_delays_monthly

correlated_data = corr_df.corr(numeric_only=True).values
y_labels = list(corr_df.corr(numeric_only=True)['ArrDelay'].index)
x_labels = y_labels

ax = sns.heatmap(
    correlated_data,
    yticklabels=y_labels,
    xticklabels=x_labels,
    cmap='coolwarm',
)
_ = ax.set_title('Correlation by Delay Count')

# %%
import seaborn as sns

arrival_delays_monthly = df['ArrDelay']
departure_delays_monthly = df['DepDelay']
carrier_delays_monthly = df['CarrierDelay']
NAS_delays_monthly = df['NASDelay']
weather_delays_monthly = df['WeatherDelay']
security_delays_monthly = df['SecurityDelay']
lateAircraft_delays_monthly = df['LateAircraftDelay']


corr_df = arrival_delays_monthly.to_frame()
corr_df['DepDelay'] = departure_delays_monthly
corr_df['CarrierDelay'] = carrier_delays_monthly
corr_df['NASDelay'] = NAS_delays_monthly
corr_df['WeatherDelay'] = weather_delays_monthly
corr_df['SecurityDelay'] = security_delays_monthly
corr_df['lateAircraftDelay'] = lateAircraft_delays_monthly

#print(corr_df)
correlated_data = corr_df.corr(numeric_only=True).values
y_labels = list(corr_df.corr(numeric_only=True)['ArrDelay'].index)
x_labels = y_labels

ax = sns.heatmap(
    correlated_data,
    yticklabels=y_labels,
    xticklabels=x_labels,
    cmap='coolwarm',
)
_ = ax.set_title('Correlation by Delay Amount')

# %% [markdown]
# ## Exercise 2: Ethical Implications

# %% [markdown]
# Even the most basic of data manipulations has the potential to affect segments of the population in different ways. It is important to consider how your code might positively and negatively affect different types of users.
#
# In this section of the project, you will reflect on the ethical implications of your analysis.

# %% [markdown]
# ### Student Solution

# %% [markdown]
# **Positive Impact**
#
# Your analysis is trying to solve a problem. Think about who will benefit if the problem is solved, and write a brief narrative about how the model will help.

# %% [markdown]
# *\[Hypothetical entities\] will benefit because...*

# %% [markdown]
# **Negative Impact**
#
# Solutions usually don't have a universal benefit. Think about who might be negatively impacted by your analysis. This person or persons might not be directly considered in the analysis, but they might be impacted indirectly.

# %% [markdown]
# *\[Hypothetical entity\] will be negatively impacted because...*

# %% [markdown]
# **Bias**
#
# Data analysis can be biased for many reasons. The bias can come from the data itself (e.g. sampling, data collection methods, available sources), and from the interpretation of the analysis outcome.
#
# Think of at least two ways that bias might have been introduced to your analysis and explain them below.

# %% [markdown]
# *One source of bias in the analysis could be...*
#
# *Another source of bias in the analysis could be...*

# %% [markdown]
# **Changing the Dataset to Mitigate Bias**
#
# The most common way that an analysis is biased is when the dataset itself is biased. Look back at the input data that you used for your analysis. Think about how you might change something about the data to reduce bias in your model.
#
# What changes could you make to make your dataset less biased? Consider the data that you have, how and where that data was collected, and what other sources of data might be used to reduce bias.
#
# Write a summary of the changes that could be made to your input data.

# %% [markdown]
# *Since the data has potential bias X, we can adjust...*

# %% [markdown]
# **Changing the Analysis Questions to Mitigate Bias**
#
# Are there any ways to reduce bias by changing the analysis itself? This could include modifying the choice of questions you ask, the approach you take to answer the questions, etc.
#
# Write a brief summary of any changes that you could make to help reduce bias in your analysis.

# %% [markdown]
# *Since the analysis has potential bias X, we can adjust...*

# %% [markdown]
# **Mitigating Bias Downstream**
#
# While analysis can point to suggestions, it is people who make decisions based on them. What processes and/or rules should be in place for people and systems interpreting and acting on the results of your analysis to reduce the bias? Describe these below.

# %% [markdown]
# *Since the analysis has potential bias X, we can implement processes...*
